# %% [markdown]
# import

# %%
# %pip install hezar
# Out:
# Collecting hezar
#   Downloading hezar-0.42.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: huggingface_hub>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from hezar) (0.36.0)
# Requirement already satisfied: omegaconf>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from hezar) (2.3.0)
# Requirement already satisfied: tokenizers>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from hezar) (0.22.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from hezar) (2.9.0+cu126)
# Requirement already satisfied: transformers>=4.28.0 in /usr/local/lib/python3.12/dist-packages (from hezar) (4.57.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.12.0->hezar) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.12.0->hezar) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.12.0->hezar) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.12.0->hezar) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.12.0->hezar) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.12.0->hezar) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.12.0->hezar) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.12.0->hezar) (1.2.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from omegaconf>=2.3.0->hezar) (4.9.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->hezar) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->hezar) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->hezar) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->hezar) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->hezar) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->hezar) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->hezar) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->hezar) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->hezar) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->hezar) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->hezar) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->hezar) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->hezar) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->hezar) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->hezar) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->hezar) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->hezar) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->hezar) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->hezar) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->hezar) (3.5.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.28.0->hezar) (2.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.28.0->hezar) (2025.11.3)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.28.0->hezar) (0.7.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.10.0->hezar) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.10.0->hezar) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.12.0->hezar) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.12.0->hezar) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.12.0->hezar) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.12.0->hezar) (2025.11.12)
# Downloading hezar-0.42.0-py3-none-any.whl (195 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.2/195.2 kB 4.2 MB/s eta 0:00:00
# Installing collected packages: hezar
# Successfully installed hezar-0.42.0

# %% [markdown]
# Import stuff

# %%
from hezar.models import Model
from datasets import load_dataset, Audio
from evaluate import load
import re
from tqdm import tqdm

# --- 1. CONFIGURATION ---
MODEL_ID = "hezarai/whisper-small-fa"
DATASET_ID = "hezarai/common-voice-13-fa"
SPLIT = "train" # Change to 'test' for real performance assessment
MAX_SAMPLES = 50  # Set to None to run on the full dataset

# --- 2. LOAD MODEL & METRICS ---
print(f"Loading Hezar model: {MODEL_ID}...")
# The Hezar Model wrapper handles the feature extractor and tokenizer automatically
whisper = Model.load(MODEL_ID)

print("Loading metrics...")
wer_metric = load("wer")
cer_metric = load("cer")

# --- 3. LOAD DATASET ---
print("Loading dataset...")
dataset = load_dataset(DATASET_ID, split=SPLIT)

# Important: Hezar expects 16kHz audio.
# We cast the column so 'datasets' handles resampling automatically.
dataset = dataset.cast_column("audio", Audio(sampling_rate=16000))

if MAX_SAMPLES:
    print(f"Selecting first {MAX_SAMPLES} samples for faster evaluation...")
    dataset = dataset.select(range(MAX_SAMPLES))

# --- 4. PERSIAN NORMALIZATION ---
# Even with a fine-tuned model, you must normalize to get valid WER/CER
def normalize_text(text):
    if not text: return ""
    text = text.lower().strip()
    text = text.replace('ي', 'ی').replace('ك', 'ک')
    text = re.sub(r'[^\w\s]', '', text) # Remove punctuation
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# --- 5. EVALUATION LOOP ---
predictions = []
references = []

print("Starting inference...")
# We iterate one by one (or you can create small batches if you have a GPU)
for sample in tqdm(dataset):
    # 1. Get Audio Array
    # Hezar's predict() can take a numpy array directly
    audio_array = sample["audio"]["array"]

    # 2. Predict
    # Hezar returns a list of dictionaries, e.g., [{'text': '...'}]
    result = whisper.predict(audio_array)
    pred_text = result[0]['text']

    # 3. Get Reference
    ref_text = sample["sentence"]

    # 4. Normalize & Store
    predictions.append(normalize_text(pred_text))
    references.append(normalize_text(ref_text))

# --- 6. COMPUTE METRICS ---
print("\nComputing metrics...")
wer = wer_metric.compute(predictions=predictions, references=references)
cer = cer_metric.compute(predictions=predictions, references=references)

print(f"--------------------------------------")
print(f"Model: {MODEL_ID}")
print(f"Split: {SPLIT} | Samples: {len(predictions)}")
print(f"--------------------------------------")
print(f"WER: {wer * 100:.2f}%")
print(f"CER: {cer * 100:.2f}%")
print(f"--------------------------------------")

# Sample output for sanity check
print(f"Ref: {references[0]}")
print(f"Pred: {predictions[0]}")
# Out:
# Loading Hezar model: hezarai/whisper-small-fa...
# Loading metrics...
# Loading dataset...
# Selecting first 50 samples for faster evaluation...
# Starting inference...
# 100%|██████████| 50/50 [23:02<00:00, 27.66s/it]
# Computing metrics...
# --------------------------------------
# Model: hezarai/whisper-small-fa
# Split: train | Samples: 50
# --------------------------------------
# WER: 6.88%
# CER: 1.65%
# --------------------------------------
# Ref: تا حرف پول به میان میآید گوشهایش را تیز میکند
# Pred: تا حرف پول به میان میآید گوشهایش را تیز میکند

# %% [markdown]
# Load dataset

# %% [markdown]
# Preprocess

# %% [markdown]
# Training HMM
